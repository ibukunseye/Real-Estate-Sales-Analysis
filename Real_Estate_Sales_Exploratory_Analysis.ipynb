# %% [markdown]
# ## Problem Statement
# -- Exploring Property Assessment and Sales Data for Informed Decision Making

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.style.use('ggplot')

# %%
df = pd.read_csv(r"C:\Users\solut\OneDrive\Desktop\Quantum Analytics- DAF-MATMARY-PC-MATMARY-PC\Python\Real_Estate_Sales_2001-2020_GL (1).csv")
df
# Out:
# C:\Users\solut\AppData\Local\Temp\ipykernel_27808\4114474279.py:1: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\solut\OneDrive\Desktop\Quantum Analytics- DAF-MATMARY-PC-MATMARY-PC\Python\Real_Estate_Sales_2001-2020_GL (1).csv")
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# ...

# %%
df.shape
# Out:
# (997213, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  int64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 106.5+ MB

# %%
df.isnull()
# Out:
#         Serial Number  List Year  Date Recorded   Town  Address  \
# 0               False      False          False  False    False
# 1               False      False          False  False    False
# 2               False      False          False  False    False
# 3               False      False          False  False    False
# 4               False      False          False  False    False
# ...               ...        ...            ...    ...      ...
# 997208          False      False          False  False    False
# 997209          False      False          False  False    False
# 997210          False      False          False  False    False
# 997211          False      False          False  False    False
# 997212          False      False          False  False    False
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 0                False        False        False          False
# 1                False        False        False          False
# ...

# %%
df.isnull().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            2
# Town                     0
# Address                 51
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type       382446
# Residential Type    388309
# Non Use Code        707532
# Assessor Remarks    847349
# OPM remarks         987279
# Location            799516
# dtype: int64

# %%
# Assuming df.isnull().sum() returns a Series
null_counts = df.isnull().sum()
null_counts_df = pd.DataFrame(null_counts, columns=['Missing Values'])

plt.figure(figsize=(10, 6))
sns.heatmap(null_counts_df.T, annot=True, cmap='viridis', cbar=True)
plt.title('Missing Values Heatmap')
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.show()

# %%
cat_cols = df.select_dtypes(include = ['category', 'object']).columns.to_list()
cat_cols
# Out:
# ['Date Recorded',
#  'Town',
#  'Address',
#  'Property Type',
#  'Residential Type',
#  'Non Use Code',
#  'Assessor Remarks',
#  'OPM remarks',
#  'Location']

# %%
num_cols = df.select_dtypes(include = ['float64', 'int64']).columns.to_list()
num_cols
# Out:
# ['Serial Number', 'List Year', 'Assessed Value', 'Sale Amount', 'Sales Ratio']

# %%
for column in cat_cols:
    print(df[column].value_counts())
# Out:
# Date Recorded
# 07/01/2005    877
# 08/01/2005    859
# 07/01/2004    840
# 06/30/2005    828
# 09/30/2005    781
#              ...
# 01/21/2006      1
# 07/07/2012      1
# 04/14/2012      1
# 07/28/2012      1
# 03/07/2020      1
# Name: count, Length: 6387, dtype: int64
# Town
# Bridgeport       34201
# Stamford         32529
# Waterbury        28506
# Norwalk          23960
# New Haven        21346
#                  ...
# Hartland           448
# Scotland           430
# Canaan             429
# Union              261
# ***Unknown***        1
# Name: count, Length: 170, dtype: int64
# Address
# MULTI ADDRESSES            620
# 8 SOUTH RD                 420
# 51 OLD SPRINGFIELD RD      172
# 312 N BISHOP AVE           114
# RIGGS ST                   106
#                           ...
# 655 120 TALCOTTVILLE RD      1
# 414 SALMON BRK ST            1
# 21 BUTTERNUT KNL             1
# 59 BURNSIDE AVE UT 2 &       1
# 126 PERKINS AVE              1
# ...

# %%
for column in num_cols:
    print(df[column].value_counts())
# Out:
# Serial Number
# 10010      172
# 10018      172
# 10002      172
# 10003      171
# 10009      171
#           ...
# 124743       1
# 124571       1
# 125068       1
# 124724       1
# 1910419      1
# Name: count, Length: 83537, dtype: int64
# List Year
# 2004    84056
# 2020    66592
# 2003    64239
# 2005    61602
# 2002    59682
# 2001    59584
# 2019    58954
# 2018    50709
# 2016    49773
# 2014    49563
# 2006    48785
# 2015    46651
# 2017    45691
# 2009    42508
# 2013    39943
# 2012    35973
# 2007    35617
# 2010    33491
# 2008    32735
# 2011    31065
# Name: count, dtype: int64
# Assessed Value
# 0          6933
# 17500       603
# 105000      553
# 35000       536
# 70000       473
#            ...
# 1802750       1
# 1192500       1
# 20886         1
# 54041         1
# 4035970       1
# Name: count, Length: 91378, dtype: int64
# Sale Amount
# 150000.0     9401
# 200000.0     8999
# 250000.0     8471
# 175000.0     7547
# 225000.0     7421
#              ...
# ...

# %% [markdown]
# ## Data Maniupulation and Validation

# %%
# fill the missing values of 'Address', 'Property Type', 'Residential type' with 'Unknown'
df['Address'] = df['Address'].astype(str).fillna('Unknown')
df['Address'] = df['Address'].replace('nan', 'Unknown')

df['Property Type'] = df['Property Type'].astype(str).fillna('Unknown')
df['Property Type'] = df['Property Type'].replace('nan', 'Unknown')

df['Residential Type'] = df['Residential Type'].astype(str).fillna('Unknown')
df['Residential Type'] = df['Residential Type'].replace('nan', 'Unknown')

df['Assessor Remarks'] = df['Assessor Remarks'].astype(str).fillna('Unknown')
df['Assessor Remarks'] = df['Assessor Remarks'].replace('nan', 'Unknown')

df['OPM remarks'] = df['OPM remarks'].astype(str).fillna('Unknown')
df['OPM remarks'] = df['OPM remarks'].replace('nan', 'Unknown')

df['Location'] = df['Location'].astype(str).fillna('Unknown')
df['Location'] = df['Location'].replace('nan', 'Unknown')

df['Non Use Code'] = df['Non Use Code'].astype(str).fillna('Unknown')
df['Non Use Code'] = df['Non Use Code'].replace('nan', 'Unknown')

df['Date Recorded'] = df['Date Recorded'].astype(str).fillna(2000)
df['Date Recorded'] = df['Date Recorded'].replace('nan', 2000)

# check the head of the column
df.head()
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020    10/02/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500     325000.0       0.4630    Commercial          Unknown
# 1          253000     430000.0       0.5883   Residential    Single Family
# 2          130400     179900.0       0.7248   Residential            Condo
# 3          619290     890000.0       0.6958   Residential    Single Family
# 4          862330    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# ...

# %%
df.isnull().sum()
# Out:
# Serial Number       0
# List Year           0
# Date Recorded       0
# Town                0
# Address             0
# Assessed Value      0
# Sale Amount         0
# Sales Ratio         0
# Property Type       0
# Residential Type    0
# Non Use Code        0
# Assessor Remarks    0
# OPM remarks         0
# Location            0
# dtype: int64

# %%
df.describe()
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   9.972130e+05  997213.000000    9.972130e+05  9.972130e+05
# mean    4.311864e+05    2010.189829    2.791437e+05  3.911512e+05
# std     6.549219e+06       6.237877    1.670610e+06  5.347270e+06
# min     0.000000e+00    2001.000000    0.000000e+00  0.000000e+00
# 25%     3.044400e+04    2004.000000    8.760000e+04  1.400000e+05
# 50%     7.030300e+04    2010.000000    1.383900e+05  2.250000e+05
# 75%     1.518780e+05    2016.000000    2.255600e+05  3.650000e+05
# max     2.000500e+09    2020.000000    8.815100e+08  5.000000e+09
#
#         Sales Ratio
# count  9.972130e+05
# mean   1.044637e+01
# std    1.890192e+03
# min    0.000000e+00
# 25%    4.867000e-01
# 50%    6.246000e-01
# 75%    7.852761e-01
# max    1.226420e+06

# %% [markdown]
# The total number of records for each variable is 997213. The mean value for Asssessed Value, Sale Amount and Sales Ratio is 2.79, 3.91, and 1.04, respectively.

# %%
df.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Assessor Remarks', 'OPM remarks',
#        'Location'],
#       dtype='object')

# %% [markdown]
# ## Assessment Accuracy Evaluate the accuracy of property assess values with actual sale amounts, and identify any discrepancies
# -- Visualise Property Assessment Values with Actual Sales Amount using the Sales Ratio

# %%
# Display the first few rows of the dataset to understand its structure
print(df.head())

# Calculate the percentage difference between assessed values and actual sale amounts
df['Percentage_Difference'] = ((df['Assessed Value'] - df['Sale Amount']) / df['Sale Amount']) * 100

# Display the updated DataFrame with the percentage difference column
print(df)

# Set a threshold for identifying discrepancies (e.g., 10% difference)
discrepancy_threshold = 10

# Identify properties with discrepancies beyond the threshold
discrepancies = df[df['Percentage_Difference'].abs() > discrepancy_threshold]

# Display properties with discrepancies
print("Properties with discrepancies:")
print(discrepancies)
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020    10/02/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500     325000.0       0.4630    Commercial          Unknown
# 1          253000     430000.0       0.5883   Residential    Single Family
# 2          130400     179900.0       0.7248   Residential            Condo
# 3          619290     890000.0       0.6958   Residential    Single Family
# 4          862330    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# ...

# %% [markdown]
# The Sales Ratio which should be 1 if the Assessed Value and Sale Amount is correct shows a significant discrepany

# %%
# Calculate the percentage difference between assessed values and actual sale amounts
df['Percentage_Difference'] = ((df['Assessed Value'] - df['Sale Amount']) / df['Sale Amount']) * 100

# Customized line chart
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Percentage_Difference'], marker='o', linestyle='-', color='r', label='Percentage Difference')

# Add labels and title
plt.title('Percentage Difference Between Assessed Values and Sale Amounts')
plt.xlabel('Property Index')
plt.ylabel('Percentage Difference')

# Customize the x-axis tick labels (optional)
plt.xticks(rotation=45, ha='right')

# Add a horizontal line at the threshold for better visualization
plt.axhline(y=discrepancy_threshold, color='black', linestyle='--', label='Threshold')
plt.axhline(y=-discrepancy_threshold, color='black', linestyle='--')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# The above chart shows the percentage difference between the Assessed Value and Actual Sale Amount of each Property. The Discrepany went as high as above 1.2%

# %% [markdown]
# ## Market Trends: Analyze sales ratios to uncover trends in property market values, understanding how sale amounts relate to the assessed values across different property types and residential classifications

# %%
columns_to_visualize = ['Sales Ratio', 'Property Type', 'Residential Type']

# Customized line chart
plt.figure(figsize=(14, 8))
sns.lineplot(x='Property Type', y='Sales Ratio', hue='Residential Type', data=df, marker='o', linestyle='-', markersize=10)

# Add labels and title
plt.title('Sales Ratio by Property Type and Residential Type')
plt.xlabel('Property Type')
plt.ylabel('Sales Ratio')

# Show the legend
plt.legend(title='Residential Type', loc='upper left', bbox_to_anchor=(1, 1))

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# Using the Sales Ratio to get the Market Trend for the Residential Type, there is a significant increase in the ratio for Residential Type- 'Unknown' as sufficient data was not provided

# %% [markdown]
# ## Geographical Analysis Investigate variations in assessed values, sales amounts, and market ratios across different towns, providing a localized understanding of real estate dynamics

# %%
Columns_to_Analyse = ['Assessed Value', 'Sale Amount', 'Sales Ratio', 'Town']

# Customized bar chart
plt.figure(figsize=(16, 8))
sns.barplot(x='Town', y='Assessed Value', data=df, color='skyblue', label='Assessed Value')
sns.barplot(x='Town', y='Sale Amount', data=df, color='orange', label='Sale Amount')
sns.barplot(x='Town', y='Sales Ratio', data=df, color='green', label='Sales Ratio')

# Add labels and title
plt.title('Comparison of Assessed Value, Sale Amount, and Sales Ratio by Town')
plt.xlabel('Town')
plt.ylabel('Values')

# Show the legend
plt.legend()

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
# Sort the DataFrame by each column
top_20_assessed_value = df.sort_values(by='Assessed Value', ascending=False).head(20)
top_20_sale_amount = df.sort_values(by='Sale Amount', ascending=False).head(20)
top_20_sales_ratio = df.sort_values(by='Sales Ratio', ascending=False).head(20)

# Create a figure and axes
fig, axes = plt.subplots(3, 1, figsize=(12, 18))

# Customized bar chart function
def customized_bar_chart(data, x_column, y_column, color, title, xlabel, ylabel, ax):
    sns.barplot(x=x_column, y=y_column, data=data, palette=color, ax=ax)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

# Customize and plot Assessed Value
customized_bar_chart(top_20_assessed_value, 'Assessed Value', 'Town', 'Blues_d',
                      'Top 20 Towns - Assessed Value', 'Assessed Value', 'Town', ax=axes[0])

# Customize and plot Sale Amount
customized_bar_chart(top_20_sale_amount, 'Sale Amount', 'Town', 'Oranges_d',
                      'Top 20 Towns - Sale Amount', 'Sale Amount', 'Town', ax=axes[1])

# Customize and plot Sales Ratio
customized_bar_chart(top_20_sales_ratio, 'Sales Ratio', 'Town', 'Greens_d',
                      'Top 20 Towns - Sales Ratio', 'Sales Ratio', 'Town', ax=axes[2])

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Using the Top 20 Towns to investigate the variations in Assessed Value, Sale Amount and Market Ratio, The above shows that Hamden is the highest in terms of Assessed Value, Willington is the highest in terms of Sale Amount and Salisbury is the highest in terms of Sales Ratio. This clearly shows that there is a great discrepancy between the Assessed Value and Actual Sale Amount.

# %% [markdown]
# ## Property Type Impact Examine the impact of property type on assessment accuracy and market trends, exploring whether certain types (e.g., residential, commercial) exhibit distinct patterns.

# %%
columns_visualization = ['Sales Ratio', 'Property Type']

# Sort the DataFrame by relevant columns if needed
df_sorted = df.sort_values(by=['Sales Ratio', 'Property Type'])

# Create a line chart for trend analysis
plt.figure(figsize=(12, 8))
sns.lineplot(x='List Year', y='Sales Ratio', hue='Property Type', data=df_sorted)
plt.title('Trend Analysis - Sales Ratio by Property Type')
plt.xlabel('List Year')  # Replace 'YourTimeColumn' with the actual time-related column
plt.ylabel('Sales Ratio')
plt.legend(title='Property Type')
plt.show()

# %% [markdown]
# Residential and Unknown Property Type have the highest Sales Ratio

# %% [markdown]
# ## Non-Use Code Insights Explore the significance of non-use codes in property assessment, investigating how these codes influence assessed values and sales transactions.

# %%
columnsVisualization = ['Non Use Code', 'Assessed Value', 'Sale Amount']

# Create a grouped bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Non Use Code', y='Assessed Value', data=df, ci=None, color='blue', label='Assessed Value')
sns.barplot(x='Non Use Code', y='Sale Amount', data=df, ci=None, color='orange', label='Sale Amount')

plt.title('Significance of Non Use Code on Assessed Value and Sale Amount')
plt.xlabel('Non Use Code')
plt.ylabel('Values')
plt.legend()

plt.show()
# Out:
# C:\Users\solut\AppData\Local\Temp\ipykernel_27808\2112272324.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Non Use Code', y='Assessed Value', data=df, ci=None, color='blue', label='Assessed Value')
# C:\Users\solut\AppData\Local\Temp\ipykernel_27808\2112272324.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Non Use Code', y='Sale Amount', data=df, ci=None, color='orange', label='Sale Amount')

# %%
# Sort the DataFrame by 'Assessed Value' and select the top 20 Non Use Codes
top_20_non_use_codes = df.sort_values(by='Assessed Value', ascending=False).head(20)

# Set a larger figure size
plt.figure(figsize=(16, 10))

# Create a grouped bar chart with data labels
sns.barplot(x='Non Use Code', y='Assessed Value', data=top_20_non_use_codes, color='blue', label='Assessed Value')

# Bar for Sale Amount
sns.barplot(x='Non Use Code', y='Sale Amount', data=top_20_non_use_codes, color='orange', label='Sale Amount')

# Add data labels for Assessed Value
for index, value in enumerate(top_20_non_use_codes['Assessed Value']):
    plt.text(index, value, f'{value:,.2f}', va='bottom', ha='center', fontsize=10)

# Add data labels for Sale Amount
for index, value in enumerate(top_20_non_use_codes['Sale Amount']):
    plt.text(index, value, f'{value:,.2f}', va='bottom', ha='center', fontsize=10)

plt.title('Top 20 Non Use Codes - Assessed Value and Sale Amount')
plt.xlabel('Non Use Code')
plt.ylabel('Values')
plt.legend()

plt.show()

# %% [markdown]
# ## Assessor and OPM Remarks Analyze remarks provided by assessors and the Office of Policy and Management (OPM) to identify factors influencing assessment decisions and potential areas for improvement.

# %%
# Assuming df is your DataFrame and 'Assessor Remarks' and 'OPM Remarks' are the columns of interest

# Create a count plot with a bright color palette
plt.figure(figsize=(12, 8))
sns.countplot(data=df, y='Assessor Remarks', order=df['Assessor Remarks'].value_counts().index, palette='bright', label='Assessor Remarks')
sns.countplot(data=df, y='OPM remarks', order=df['OPM remarks'].value_counts().index, palette='bright', label='OPM Remarks')

plt.title('Distribution of Assessor and OPM Remarks')
plt.xlabel('Count')
plt.ylabel('Remarks')
plt.legend()

plt.show()

# %% [markdown]
# # Recommendation: The OPM and Assesser Remarks will need to be critically assessed and if possible proper training provided so that going forward Property Assessment done will be near accurate with little or no error at all.
